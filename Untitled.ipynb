# %%
import matplotlib.pyplot as plt

infile = './d4.png'
img = plt.imread(infile)
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (249, 361, 4)

# %%
img.dtype
# Out:
# dtype('float32')

# %%
img[:150,:300,0] = 1.0

# %%
plt.imshow(img)

# %%
img[150:249 , 150:361 , 0] = 1- img[150:249 , 150:361 , 0]
img[150:249 , 150:361 , 1] = 1- img[150:249 , 150:361 , 1]
img[150:249 , 150:361 , 2] = 1- img[150:249 , 150:361 , 2]

# %%
plt.imshow(img)
